# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.loc[1] # this looks for index as set of the dataframe
# Out:
# ID                                   2
# Name                          A Lamusi
# Sex                                  M
# Age                                 23
# Height                             170
# Weight                              60
# Team                             China
# NOC                                CHN
# Games                      2012 Summer
# Year                              2012
# Season                          Summer
# City                            London
# Sport                             Judo
# Event     Judo Men's Extra-Lightweight
# Medal                              NaN
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City     Sport  \
# 1  2012 Summer  2012  Summer     London      Judo
# 2  1920 Summer  1920  Summer  Antwerpen  Football
#
#                           Event Medal
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
df.Age.idxmax()
# Out:
# 257054

# %%
df[(df.Age == 23.0) & (df.City == 'London')].head()
# Out:
#       ID                                          Name Sex   Age  Height  \
# 1      2                                      A Lamusi   M  23.0   170.0
# 434  241                  Sayed Abdelmonem Sayed Hamed   M  23.0   170.0
# 436  243         Ihab Abdelrahman El-Sayed Abdelrahman   M  23.0   194.0
# 598  344  Amer Abdulrahman Abdallah Hussain Al-Hammadi   M  23.0   168.0
# 612  353                                Rasul Abduraim   M  23.0   183.0
#
#      Weight                  Team  NOC        Games  Year  Season    City  \
# 1      60.0                 China  CHN  2012 Summer  2012  Summer  London
# 434    60.0                 Egypt  EGY  2012 Summer  2012  Summer  London
# 436    96.0                 Egypt  EGY  2012 Summer  2012  Summer  London
# 598    68.0  United Arab Emirates  UAE  2012 Summer  2012  Summer  London
# 612    74.0            Kyrgyzstan  KGZ  2012 Summer  2012  Summer  London
#
#          Sport                                     Event Medal
# ...

# %%
df.groupby('Medal').Age.count()
# Out:
# Medal
# Bronze    13006
# Gold      13224
# Silver    12821
# Name: Age, dtype: int64

# %%
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City     Sport  \
# 1  2012 Summer  2012  Summer     London      Judo
# 2  1920 Summer  1920  Summer  Antwerpen  Football
#
#                           Event Medal
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN
