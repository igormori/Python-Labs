# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

# %%
df =pd.read_csv('athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#< ----------------------   1 -Youngest and oldest participants ---------------------------------------->


# Note that the youngest participant was 10 and the oldest 97 ! Find who they are and what sports they cometed in.

# hint: read about idxmin() function


df.Age.idxmax()
# Out:
# 257054

# %%
df.Age.idxmin()
# Out:
# 142882

# %%
df.loc[[257054, 142882]]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
# 142882   71691      Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season  \
# 257054                  United States  USA  1928 Summer  1928  Summer
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer
#
#              City             Sport  \
# 257054  Amsterdam  Art Competitions
# 142882     Athina        Gymnastics
#
#                                               Event   Medal
# 257054  Art Competitions Mixed Sculpturing, Statues     NaN
# 142882        Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
#< ----------------------   2 -How many unique athletes are listed in the dataset? ---------------------------------------->




df.ID.count()
# Out:
# 271116

# %%
#< ----------------------   2 -How many unique athletes got any medals?---------------------------------------->




df.Medal.count()
# Out:
# 39783

# %%
#< ----------------------   3 -How many medals of each type were awarded? ---------------------------------------->




df.groupby('Medal').ID.count()
# Out:
# Medal
# Bronze    13295
# Gold      13372
# Silver    13116
# Name: ID, dtype: int64

# %%
#< ----------------------   4 -Waht's the newest olympic sport in this dataset? ---------------------------------------->


df.Year.sort_values(ascending=False).head()
# Out:
# 236646    2016
# 47746     2016
# 47728     2016
# 47729     2016
# 142355    2016
# Name: Year, dtype: int64

# %%
df.Sport.loc[236646]
# Out:
# 'Hockey'

# %%
#< ----------------------   5 -What sport had the most participants in the latest summer games? ---------------------------------------->



lastSummer =df[df.Games == '2016 Summer']
lastSummer.groupby('Sport').ID.count().idxmax()
# Out:
# 'Athletics'

# %%
#< ----------------------   6 -List all the cities that hosted any olympic games more than once ------------------------------>



counts = df['City'].value_counts()
df[df['City'].isin(counts.index[counts > 1])].drop_duplicates(subset='City')
# Out:
#        ID                                Name Sex   Age  Height  Weight  \
# 0       1                           A Dijiang   M  24.0   180.0    80.0
# 1       2                            A Lamusi   M  23.0   170.0    60.0
# 2       3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3       4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4       5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6       5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8       5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 26      8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 28      9                    Antti Sami Aalto   M  26.0   186.0    96.0
# 29     10      Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# 30     11                  Jorma Ilmari Aalto   M  22.0   182.0    76.5
# 31     12                   Jyri Tapani Aalto   M  31.0   172.0    70.0
# ...

# %%
#< ----------------------   7 -Plot histograms of Age, Height and Weight of athletes ------------------------------>





sns.set()   # to display in a nice format
plt.hist(df.Age.dropna(), alpha=0.9, color='Red', bins=20)
plt.xlabel("Athlets Age")
# Out:
# Text(0.5,0,'Athlets Age')

# %%
sns.set()   # to display in a nice format
plt.hist(df.Height.dropna(), alpha=0.9, color='Green', bins=10)
plt.xlabel("Athlets Heights")
# Out:
# Text(0.5,0,'Athlets Heights')

# %%
sns.set()   # to display in a nice format
df.hist(['Age','Weight'], bins=30)#dropna() functions removes the NaN values making possible to plot
# this is how to display two in the same line
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B147E3438>,
# ...
#       dtype=object)

# %%
sns.set()   # to display in a nice format
weight_f = df.Weight[df.Sex == "F"] 
plt.hist(weight.dropna(), alpha=0.9, color='Pink', bins=10)
# Out:
# (array([6.0000e+01, 3.0545e+04, 7.7079e+04, 2.9312e+04, 3.4290e+03,
#         8.2300e+02, 1.7800e+02, 3.6000e+01, 5.0000e+00, 3.0000e+00]),
#  array([ 28. ,  46.6,  65.2,  83.8, 102.4, 121. , 139.6, 158.2, 176.8,
#         195.4, 214. ]),
#  <a list of 10 Patch objects>)

# %%
weight_m = df.Weight[df.Sex == "M"] 
plt.hist(weight_m.dropna(), alpha=0.9, color='Blue', bins=10, label="M")
plt.hist(weight_f.dropna(), alpha=0.9, color='Pink', bins=10,label="F")
# Out:
# (array([1.0370e+03, 1.5061e+04, 3.7517e+04, 1.1486e+04, 1.3020e+03,
#         2.3400e+02, 8.0000e+01, 4.0000e+01, 9.0000e+00, 5.0000e+00]),
#  array([ 25. ,  39.2,  53.4,  67.6,  81.8,  96. , 110.2, 124.4, 138.6,
#         152.8, 167. ]),
#  <a list of 10 Patch objects>)

# %%
#< ----------------------   7 -Here is an attempt to plot the number of participants as a function of year. 
#-----------------------       What happaned in mid 1990s that makes this graph look so weird? Plot a more useful 
#-----------------------       graph (or several)                                                ------------------------------>




df.groupby(['Year'])['ID'].count().plot()
plt.grid()

# %%
df.hist(['Age', 'Height'], bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B13E0C3C8>,
# ...
#       dtype=object)
